# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conn = sqlite3.connect("olist.sqlite")
cur = conn.cursor()

# %%
query = "SELECT name FROM sqlite_master WHERE type = 'table'"
cur.execute(query)
cur.fetchall()
# Out:
# [('product_category_name_translation',),
#  ('sellers',),
#  ('customers',),
#  ('geolocation',),
#  ('order_items',),
#  ('order_payments',),
#  ('order_reviews',),
#  ('orders',),
#  ('products',),
#  ('leads_qualified',),
#  ('leads_closed',)]

# %%
query = "PRAGMA table_info(product_category_name_translation)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'product_category_name', 'TEXT', 0, None, 0),
#  (1, 'product_category_name_english', 'TEXT', 0, None, 0)]

# %%
query = "PRAGMA table_info(sellers)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'seller_id', 'TEXT', 0, None, 0),
#  (1, 'seller_zip_code_prefix', 'INTEGER', 0, None, 0),
#  (2, 'seller_city', 'TEXT', 0, None, 0),
#  (3, 'seller_state', 'TEXT', 0, None, 0)]

# %%
query = "PRAGMA table_info(customers)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'customer_id', 'TEXT', 0, None, 0),
#  (1, 'customer_unique_id', 'TEXT', 0, None, 0),
#  (2, 'customer_zip_code_prefix', 'INTEGER', 0, None, 0),
#  (3, 'customer_city', 'TEXT', 0, None, 0),
#  (4, 'customer_state', 'TEXT', 0, None, 0)]

# %%
query = "PRAGMA table_info(geolocation)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'geolocation_zip_code_prefix', 'INTEGER', 0, None, 0),
#  (1, 'geolocation_lat', 'REAL', 0, None, 0),
#  (2, 'geolocation_lng', 'REAL', 0, None, 0),
#  (3, 'geolocation_city', 'TEXT', 0, None, 0),
#  (4, 'geolocation_state', 'TEXT', 0, None, 0)]

# %%
query = "PRAGMA table_info(order_items)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'order_id', 'TEXT', 0, None, 0),
#  (1, 'order_item_id', 'INTEGER', 0, None, 0),
#  (2, 'product_id', 'TEXT', 0, None, 0),
#  (3, 'seller_id', 'TEXT', 0, None, 0),
#  (4, 'shipping_limit_date', 'TEXT', 0, None, 0),
#  (5, 'price', 'REAL', 0, None, 0),
#  (6, 'freight_value', 'REAL', 0, None, 0)]

# %%
query = "PRAGMA table_info(order_payments)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'order_id', 'TEXT', 0, None, 0),
#  (1, 'payment_sequential', 'INTEGER', 0, None, 0),
#  (2, 'payment_type', 'TEXT', 0, None, 0),
#  (3, 'payment_installments', 'INTEGER', 0, None, 0),
#  (4, 'payment_value', 'REAL', 0, None, 0)]

# %%
query = "PRAGMA table_info(order_reviews)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'review_id', 'TEXT', 0, None, 0),
#  (1, 'order_id', 'TEXT', 0, None, 0),
#  (2, 'review_score', 'INTEGER', 0, None, 0),
#  (3, 'review_comment_title', 'TEXT', 0, None, 0),
#  (4, 'review_comment_message', 'TEXT', 0, None, 0),
#  (5, 'review_creation_date', 'TEXT', 0, None, 0),
#  (6, 'review_answer_timestamp', 'TEXT', 0, None, 0)]

# %%
query = "PRAGMA table_info(orders)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'order_id', 'TEXT', 0, None, 0),
#  (1, 'customer_id', 'TEXT', 0, None, 0),
#  (2, 'order_status', 'TEXT', 0, None, 0),
#  (3, 'order_purchase_timestamp', 'TEXT', 0, None, 0),
#  (4, 'order_approved_at', 'TEXT', 0, None, 0),
#  (5, 'order_delivered_carrier_date', 'TEXT', 0, None, 0),
#  (6, 'order_delivered_customer_date', 'TEXT', 0, None, 0),
#  (7, 'order_estimated_delivery_date', 'TEXT', 0, None, 0)]

# %%
query = "PRAGMA table_info(products)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'product_id', 'TEXT', 0, None, 0),
#  (1, 'product_category_name', 'TEXT', 0, None, 0),
#  (2, 'product_name_lenght', 'REAL', 0, None, 0),
#  (3, 'product_description_lenght', 'REAL', 0, None, 0),
#  (4, 'product_photos_qty', 'REAL', 0, None, 0),
#  (5, 'product_weight_g', 'REAL', 0, None, 0),
#  (6, 'product_length_cm', 'REAL', 0, None, 0),
#  (7, 'product_height_cm', 'REAL', 0, None, 0),
#  (8, 'product_width_cm', 'REAL', 0, None, 0)]

# %%
query = "PRAGMA table_info(leads_qualified)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'mql_id', 'TEXT', 0, None, 0),
#  (1, 'first_contact_date', 'TEXT', 0, None, 0),
#  (2, 'landing_page_id', 'TEXT', 0, None, 0),
#  (3, 'origin', 'TEXT', 0, None, 0)]

# %%
query = "PRAGMA table_info(leads_closed)"
cur.execute(query)
cur.fetchall()
# Out:
# [(0, 'mql_id', 'TEXT', 0, None, 0),
#  (1, 'seller_id', 'TEXT', 0, None, 0),
#  (2, 'sdr_id', 'TEXT', 0, None, 0),
#  (3, 'sr_id', 'TEXT', 0, None, 0),
#  (4, 'won_date', 'TEXT', 0, None, 0),
#  (5, 'business_segment', 'TEXT', 0, None, 0),
#  (6, 'lead_type', 'TEXT', 0, None, 0),
#  (7, 'lead_behaviour_profile', 'TEXT', 0, None, 0),
#  (8, 'has_company', 'INTEGER', 0, None, 0),
#  (9, 'has_gtin', 'INTEGER', 0, None, 0),
#  (10, 'average_stock', 'TEXT', 0, None, 0),
#  (11, 'business_type', 'TEXT', 0, None, 0),
#  (12, 'declared_product_catalog_size', 'REAL', 0, None, 0),
#  (13, 'declared_monthly_revenue', 'REAL', 0, None, 0)]

# %% [markdown]
# # **Sales and Revenue Analysis**

# %% [markdown]
# # Payment Types

# %%
query = """SELECT payment_type, COUNT(payment_value) as Payments_Count FROM order_payments
GROUP BY payment_type
ORDER BY SUM(payment_value) DESC
;"""
pd.read_sql(query, conn)
# Out:
#   payment_type  Payments_Count
# 0  credit_card           76795
# 1       boleto           19784
# 2      voucher            5775
# 3   debit_card            1529
# 4  not_defined               3

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_sql_query(query, conn)
df = df.drop(df.index[-1])
plt.figure(figsize=(8, 5))
plt.bar(df['payment_type'], df['Payments_Count'], color='skyblue')
plt.title('Payment Type Distribution', fontsize=16)
plt.xlabel('Payment Type')
plt.ylabel('Number of Payments')
plt.show()

# %%
query = """SELECT payment_type, AVG(payment_value) as AVG_payment FROM order_payments
GROUP BY payment_type
ORDER BY SUM(payment_value) DESC
;"""
pd.read_sql(query, conn)
# Out:
#   payment_type  AVG_payment
# 0  credit_card   163.319021
# 1       boleto   145.034435
# 2      voucher    65.703354
# 3   debit_card   142.570170
# 4  not_defined     0.000000

# %%
data = pd.read_sql_query(query, conn)
data_sorted = data.sort_values(by='AVG_payment', ascending=False)
data_sorted = data_sorted.drop(data_sorted.index[-1])
data_sorted.plot(
    x='payment_type',
    y='AVG_payment',
    kind='barh',
    figsize=(10, 6),
    color='lightgreen',
    legend=False
)

plt.title('Average Payment by Payment Type', fontsize=16)
plt.xlabel('Average Payment', fontsize=14)
plt.ylabel('Payment Type', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Revenues

# %%
query = "SELECT order_id, product_id, seller_id, price+freight_value as Revenue FROM order_items ;"
pd.read_sql(query, conn)
# Out:
#                                 order_id                        product_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 112645  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 112646  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 112647  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 112648  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 112649  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
#                                seller_id  Revenue
# ...

# %%
query = """SELECT  products.product_category_name, SUM(price+freight_value) as Revenue FROM order_items
JOIN products ON order_items.product_id = products.product_id
GROUP BY products.product_category_name
;"""
pd.read_sql(query, conn)
# Out:
#         product_category_name    Revenue
# 0                        None  207705.09
# 1   agro_industria_e_comercio   78374.07
# 2                   alimentos   36664.44
# 3           alimentos_bebidas   19687.47
# 4                       artes   28247.81
# ..                        ...        ...
# 69    sinalizacao_e_seguranca   28017.05
# 70   tablets_impressao_imagem    8754.61
# 71                  telefonia  394883.32
# 72             telefonia_fixa   64220.81
# 73      utilidades_domesticas  778397.77
#
# [74 rows x 2 columns]

# %% [markdown]
# # Revenue from Products sorted by Categories

# %%
query = """SELECT  product_category_name_translation.product_category_name_english, SUM(price+freight_value) as Revenue FROM order_items
JOIN products ON order_items.product_id = products.product_id
JOIN product_category_name_translation ON products.product_category_name = product_category_name_translation.product_category_name
GROUP BY product_category_name_translation.product_category_name_english
;"""
pd.read_sql(query, conn)
# Out:
#    product_category_name_english     Revenue
# 0     agro_industry_and_commerce    78374.07
# 1               air_conditioning    61774.19
# 2                            art    28247.81
# 3          arts_and_craftmanship     2184.14
# 4                          audio    56398.94
# ..                           ...         ...
# 66                    stationery   277741.71
# 67        tablets_printing_image     8754.61
# 68                     telephony   394883.32
# 69                          toys   561372.55
# 70                 watches_gifts  1305541.61
#
# [71 rows x 2 columns]

# %% [markdown]
# #Product Categories with highest Revenue in English

# %%
query = """

SELECT product_category_name_translation.product_category_name_english, ROUND(SUM(order_items.price),2), COUNT(*)
FROM order_items
JOIN products ON products.product_id = order_items.product_id
JOIN product_category_name_translation ON product_category_name_translation.product_category_name = products.product_category_name
GROUP BY products.product_category_name
ORDER BY SUM(order_items.price) DESC

LIMIT 10 """

pd.read_sql(query, conn)
# Out:
#   product_category_name_english  ROUND(SUM(order_items.price),2)  COUNT(*)
# 0                 health_beauty                       1258681.34      9670
# 1                 watches_gifts                       1205005.68      5991
# 2                bed_bath_table                       1036988.68     11115
# 3                sports_leisure                        988048.97      8641
# 4         computers_accessories                        911954.32      7827
# 5               furniture_decor                        729762.49      8334
# 6                    cool_stuff                        635290.85      3796
# 7                    housewares                        632248.66      6964
# 8                          auto                        592720.11      4235
# 9                  garden_tools                        485256.46      4347

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
# Query for Product Categories with Highest Revenue
query_revenue = """
SELECT product_category_name_translation.product_category_name_english AS product_category,
       ROUND(SUM(order_items.price), 2) AS revenue,
       COUNT(*) AS order_count
FROM order_items
JOIN products ON products.product_id = order_items.product_id
JOIN product_category_name_translation
ON product_category_name_translation.product_category_name = products.product_category_name
GROUP BY products.product_category_name
ORDER BY SUM(order_items.price) DESC
LIMIT 10
"""
revenue_data = pd.read_sql(query_revenue, conn)

# Plotly Sunburst Visualization
fig = px.sunburst(revenue_data,
                  path=['product_category'],
                  values='revenue',
                  color='order_count',
                  color_continuous_scale='Viridis',
                  title='Top 10 Product Categories: Revenue & Orders',
                  hover_data={'revenue': True, 'order_count': True})
fig.update_traces(textinfo='label+percent parent')  # Show percentage relative to the parent category
fig.update_layout(title_font_size=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Simulate the revenue_data DataFrame (replace this with your actual DataFrame)
revenue_data = pd.DataFrame({
    'product_category': ['health_beauty', 'watches_gifts', 'bed_bath_table', 'sports_leisure', 'computers_accessories',
                         'furniture_decor', 'cool_stuff', 'housewares', 'auto', 'garden_tools'],
    'revenue': [1258681.34, 1205005.68, 1036988.68, 988048.97, 911954.32, 729762.49, 635290.85, 632248.66, 592720.11, 485256.46]
})

# Simulate "year" or "time" data to animate changes over time
# Add a column for animation purposes (you can replace this with real time-series data)
years = ['2020', '2021', '2022', '2023']
revenue_data_animated = pd.concat([revenue_data.assign(year=year) for year in years], ignore_index=True)

# Simulate revenue changes over time (for demonstration, add some variation)
import numpy as np
np.random.seed(42)
revenue_data_animated['revenue'] *= (1 + 0.1 * np.random.randn(len(revenue_data_animated)))

# Create the animated bubble chart
fig = px.scatter(
    revenue_data_animated,
    x='product_category',
    y='revenue',
    size='revenue',
    color='product_category',
    animation_frame='year',  # Add animation frame based on year
    hover_name='product_category',
    size_max=60,
    title='Top 10 Product Categories by Revenue Over Time (Bubble Chart)'
)

# Update marker and layout for better visualization
fig.update_traces(marker=dict(opacity=0.7, line=dict(width=1, color='DarkSlateGrey')))
fig.update_layout(
    title_font_size=20,
    xaxis_title=None,
    yaxis_title="Revenue",
    xaxis={'categoryorder': 'total ascending'}
)

# Show the animated plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Top5-selling products

# %%
query = """SELECT  product_category_name_translation.product_category_name_english as Mostly_sold_product_type, SUM(price+freight_value) as Revenue FROM order_items
JOIN products ON order_items.product_id = products.product_id
JOIN product_category_name_translation ON products.product_category_name = product_category_name_translation.product_category_name
GROUP BY product_category_name_translation.product_category_name_english
ORDER BY
    Revenue DESC
Limit 5
;"""
pd.read_sql(query, conn)
# Out:
#   Mostly_sold_product_type     Revenue
# 0            health_beauty  1441248.07
# 1            watches_gifts  1305541.61
# 2           bed_bath_table  1241681.72
# 3           sports_leisure  1156656.48
# 4    computers_accessories  1059272.40

# %%
df = pd.read_sql_query(query, conn)
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='Mostly_sold_product_type', y='Revenue', palette='mako')

plt.title('Top 5 Selling Product Types by Revenue', fontsize=14)
plt.xlabel('Product Type', fontsize=12)
plt.ylabel('Revenue (in $)', fontsize=12)

plt.xticks(rotation=45)

plt.show()
# Out:
# <ipython-input-28-5d2fc34546a2>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # **Seller data**

# %%
query = "SELECT * FROM sellers LIMIT 5;"
pd.read_sql(query, conn)
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# Most of the sellers' locations

# %%
query = """SELECT seller_city, COUNT(seller_zip_code_prefix) as NumberOfSellers FROM sellers
GROUP BY sellers.seller_city
ORDER BY
    NumberOfSellers DESC
Limit 10;"""
pd.read_sql(query, conn)
# Out:
#       seller_city  NumberOfSellers
# 0       sao paulo              694
# 1        curitiba              127
# 2  rio de janeiro               96
# 3  belo horizonte               68
# 4  ribeirao preto               52
# 5       guarulhos               50
# 6        ibitinga               49
# 7     santo andre               45
# 8        campinas               41
# 9         maringa               40

# %%
df_Seller_cities = pd.read_sql_query(query, conn)
plt.figure(figsize=(10, 6))
sns.barplot(data=df_Seller_cities, y='seller_city', x='NumberOfSellers', palette='viridis')

plt.title('Top 10 Cities by Number of Sellers', fontsize=14)
plt.xlabel('Number of Sellers', fontsize=12)
plt.ylabel('City', fontsize=12)
# Out:
# <ipython-input-31-4a9a6bddb489>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# Text(0, 0.5, 'City')

# %%
query = """

SELECT seller_id, SUM(price), COUNT(seller_id) FROM order_items
GROUP BY seller_id
ORDER BY SUM(price) DESC

LIMIT 10 """
pd.read_sql(query, conn)
# Out:
#                           seller_id  SUM(price)  COUNT(seller_id)
# 0  4869f7a5dfa277a7dca6462dcf3b52b2   229472.63              1156
# 1  53243585a1d6dc2643021fd1853d8905   222776.05               410
# 2  4a3ca9315b744ce9f8e9374361493884   200472.92              1987
# 3  fa1c13f2614d7b5c4749cbc52fecda94   194042.03               586
# 4  7c67e1448b00f6e969d365cea6b010ab   187923.89              1364
# 5  7e93a43ef30c4f03f38b393420bc753a   176431.87               340
# 6  da8622b14eb17ae2831f4ac5b9dab84a   160236.57              1551
# 7  7a67c85e85bb2ce8582c35f2203ad736   141745.53              1171
# 8  1025f0e2d44d7041d6cf58b6550e0bfa   138968.55              1428
# 9  955fee9216a65b617aa5c0531780ce60   135171.70              1499

# %%
#Calculating the total revenue per seller will show which sellers contribute the most to sales.

seller_revenue_df = pd.read_sql("SELECT order_items.price, order_items.seller_id FROM order_items", conn)
seller_revenue = seller_revenue_df.groupby('seller_id')['price'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
seller_revenue.plot(kind='bar', color='green')
plt.title('Top Sellers by Total Revenue')
plt.xlabel('Seller ID')
plt.ylabel('Total Revenue')
plt.show()

# %%
seller_revenue_df = pd.read_sql("SELECT order_items.price, order_items.seller_id FROM order_items", conn)
seller_revenue = seller_revenue_df.groupby('seller_id')['price'].sum().sort_values(ascending=False).head(10)

dynamic_names = ['Dinosaur', 'Crocodile', 'Penguin', 'Lion', 'Eagle', 'Tiger', 'Shark', 'Bear', 'Wolf', 'Falcon']
seller_revenue_named = pd.DataFrame({
    'Seller Name': dynamic_names[:len(seller_revenue)],
    'Total Revenue': seller_revenue.values,
    'Seller ID': seller_revenue.index
})


fig = px.bar(
    seller_revenue_named,
    x='Seller Name',
    y='Total Revenue',
    hover_data={'Seller ID': True, 'Total Revenue': ':.2f'},
    title='Top Sellers by Total Revenue',
    color='Total Revenue',
    text_auto='.2s'
)

fig.update_traces(marker_line_width=1.5, marker_line_color="black")
fig.update_layout(
    xaxis_title="Seller Name",
    yaxis_title="Total Revenue",
    hovermode="x unified"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Top 10 Sellers by Number of Orders

query = """

SELECT seller_id, SUM(price), COUNT(seller_id) FROM order_items
GROUP BY seller_id
ORDER BY COUNT(seller_id) DESC

LIMIT 10 """

pd.read_sql(query, conn)
# Out:
#                           seller_id  SUM(price)  COUNT(seller_id)
# 0  6560211a19b47992c3666cc44a7e94c0   123304.83              2033
# 1  4a3ca9315b744ce9f8e9374361493884   200472.92              1987
# 2  1f50f920176fa81dab994f9023523100   106939.21              1931
# 3  cc419e0650a3c5ba77189a1882b7556a   104288.42              1775
# 4  da8622b14eb17ae2831f4ac5b9dab84a   160236.57              1551
# 5  955fee9216a65b617aa5c0531780ce60   135171.70              1499
# 6  1025f0e2d44d7041d6cf58b6550e0bfa   138968.55              1428
# 7  7c67e1448b00f6e969d365cea6b010ab   187923.89              1364
# 8  ea8482cd71df3c1969d7b9473ff13abc    37177.52              1203
# 9  7a67c85e85bb2ce8582c35f2203ad736   141745.53              1171

# %%
query = """

SELECT seller_id, SUM(price), COUNT(*) FROM order_items
JOIN orders ON orders.order_id = order_items.order_id
WHERE order_status = 'delivered'
GROUP BY seller_id
ORDER BY SUM(price) DESC

LIMIT 5
"""
pd.read_sql(query, conn)
# Out:
#                           seller_id  SUM(price)  COUNT(*)
# 0  4869f7a5dfa277a7dca6462dcf3b52b2   226987.93      1148
# 1  53243585a1d6dc2643021fd1853d8905   217940.44       400
# 2  4a3ca9315b744ce9f8e9374361493884   196882.12      1949
# 3  fa1c13f2614d7b5c4749cbc52fecda94   190917.14       579
# 4  7c67e1448b00f6e969d365cea6b010ab   186570.05      1355

# %% [markdown]
# # Customer data

# %%
query = """SELECT customer_city, COUNT(customer_zip_code_prefix) as NumberOfCustomers FROM customers
GROUP BY customers.customer_city
ORDER BY
    NumberOfCustomers DESC
Limit 10;"""
pd.read_sql(query, conn)
# Out:
#            customer_city  NumberOfCustomers
# 0              sao paulo              15540
# 1         rio de janeiro               6882
# 2         belo horizonte               2773
# 3               brasilia               2131
# 4               curitiba               1521
# 5               campinas               1444
# 6           porto alegre               1379
# 7               salvador               1245
# 8              guarulhos               1189
# 9  sao bernardo do campo                938

# %%
df_cust_cities = pd.read_sql_query(query, conn)
plt.figure(figsize=(10, 6))
sns.barplot(data=df_cust_cities, y='customer_city', x='NumberOfCustomers', palette='viridis')

plt.title('Top 10 Cities by Number of Sellers', fontsize=14)
plt.xlabel('Number of Sellers', fontsize=12)
plt.ylabel('City', fontsize=12)
# Out:
# <ipython-input-37-e13f6e584fec>:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# Text(0, 0.5, 'City')

# %%
query = """
SELECT
sellers.seller_city,
product_category_name_translation.product_category_name_english as product_type,
order_items.product_id
FROM sellers
JOIN order_items ON sellers.seller_id = order_items.seller_id
JOIN products ON order_items.product_id = products.product_id
JOIN product_category_name_translation ON products.product_category_name = product_category_name_translation.product_category_name
GROUP BY sellers.seller_city
;"""
pd.read_sql(query, conn)
# Out:
#          seller_city      product_type                        product_id
# 0           04482255     health_beauty  f1f41c991881dc3d4cbcedade3ec1622
# 1    abadia de goias     health_beauty  80d63636780c5975e5c93b63236d481d
# 2     afonso claudio   furniture_decor  787a1badb775a6b23cb25c99ba3d4b24
# 3    aguas claras df    sports_leisure  6f26402132b4c218396901cc4cf2804a
# 4           alambari        housewares  c89796b4dc35a085daa9770ed28ad589
# ..               ...               ...                               ...
# 599    volta redonda        cool_stuff  1b11571a0535a643bb18db34b84b7334
# 600       votorantim    bed_bath_table  053c1c7045cfb67d04d8c5a8dc9fc054
# 601      votuporanga  small_appliances  3e0bc37e01b5c85e125dbaef7cc3f0ad
# 602          xanxere              auto  6bbec39677851d73c72b2e8f256f34ad
# 603            xaxim        cool_stuff  02357c69f595e004b50ba115b3f88d63
#
# [604 rows x 3 columns]

# %% [markdown]
# # Customer buying frequency

# %%
query = "SELECT customer_unique_id, COUNT(customer_unique_id) AS Purchase_Count FROM customers GROUP BY customer_unique_id;"
pd.read_sql(query, conn)
# Out:
#                      customer_unique_id  Purchase_Count
# 0      0000366f3b9a7992bf8c76cfdf3221e2               1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f               1
# 2      0000f46a3911fa3c0805444483337064               1
# 3      0000f6ccb0745a6a4b88665a16c9f078               1
# 4      0004aac84e0df4da2b147fca70cf8255               1
# ...                                 ...             ...
# 96091  fffcf5a5ff07b0908bd4e2dbc735a684               1
# 96092  fffea47cd6d3cc0a88bd621562a9d061               1
# 96093  ffff371b4d645b6ecea244b27531430a               1
# 96094  ffff5962728ec6157033ef9805bacc48               1
# 96095  ffffd2657e2aad2907e67c3e9daecbeb               1
#
# [96096 rows x 2 columns]

# %% [markdown]
# # Top 5 customers

# %%
query = "SELECT customer_unique_id, COUNT(customer_unique_id) AS Purchase_Count FROM customers GROUP BY customer_unique_id ORDER BY Purchase_Count DESC Limit 5;"
pd.read_sql(query, conn)
# Out:
#                  customer_unique_id  Purchase_Count
# 0  8d50f5eadf50201ccdcedfb9e2ac8455              17
# 1  3e43e6105506432c953e165fb2acf44c               9
# 2  ca77025e7201e3b30c44b472ff346268               7
# 3  6469f99c1f9dfae7733b25662e7f1782               7
# 4  1b6c7548a2a1f9037c1fd3ddfed95f33               7

# %% [markdown]
# # Orders Analysis

# %%
# Seller City Order Analysis (Delivered Orders Only)
query = """

SELECT sellers.seller_city,
SUM(price) AS Sales,
COUNT(*) AS Count
FROM order_items
JOIN sellers ON sellers.seller_id = order_items.seller_id
JOIN orders ON orders.order_id = order_items.order_id
WHERE orders.order_status = 'delivered'
GROUP BY sellers.seller_city
ORDER BY SUM(price) DESC

LIMIT 10

"""

cur.execute(query)
cur.fetchall()
pd.read_sql(query, conn)
# Out:
#         seller_city       Sales  Count
# 0         sao paulo  2628634.52  27357
# 1          ibitinga   614836.09   7621
# 2          curitiba   458812.03   2955
# 3    rio de janeiro   342341.64   2356
# 4         guarulhos   318217.59   2309
# 5    ribeirao preto   267478.85   2208
# 6   itaquaquecetuba   228460.34   1639
# 7           guariba   226987.93   1148
# 8       santo andre   223280.71   2886
# 9  lauro de freitas   220689.44    401

# %%
# Query for Seller City Order Analysis (Delivered Orders Only)
query_city = """
SELECT sellers.seller_city,
SUM(price) AS Sales,
COUNT(*) AS Count
FROM order_items
JOIN sellers ON sellers.seller_id = order_items.seller_id
JOIN orders ON orders.order_id = order_items.order_id
WHERE orders.order_status = 'delivered'
GROUP BY sellers.seller_city
ORDER BY SUM(price) DESC
LIMIT 10
"""
city_data = pd.read_sql(query_city, conn)

# Matplotlib Visualization
plt.figure(figsize=(10, 6))
plt.barh(city_data['seller_city'], city_data['Sales'], color='darkorange')
plt.xlabel('Total Sales (in BRL)', fontsize=12)
plt.ylabel('Seller City', fontsize=12)
plt.title('Top 10 Seller Cities by Sales (Delivered Orders)', fontsize=16)
plt.gca().invert_yaxis()  # Invert y-axis for better readability
plt.tight_layout()
plt.show()

# %%
# Seaborn Visualization
city_data_sorted = city_data.sort_values(by='Count', ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x='Count', y='seller_city', data=city_data_sorted, palette='coolwarm')
plt.xlabel('Number of Delivered Orders', fontsize=12)
plt.ylabel('Seller City', fontsize=12)
plt.title('Top 10 Seller Cities by Number of Delivered Orders', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-77-901a419ddbf9>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
query = """

SELECT
Count(order_id) AS 'Total orders',
(SELECT COUNT(*) FROM orders WHERE orders.order_status = 'delivered') AS 'Delivered Orders',
(SELECT COUNT(*) FROM orders WHERE orders.order_status = 'delivered')*100 / Count(order_id) AS 'Delivered %'
FROM orders

"""
cur.execute(query)
cur.fetchall()

pd.read_sql(query, conn)
# Out:
#    Total orders  Delivered Orders  Delivered %
# 0         99441             96478           97

# %%
query = """

SELECT
Count(order_id) AS 'Total orders',
(SELECT COUNT(*) FROM orders WHERE orders.order_status = 'canceled') AS 'Canceled Orders',
(SELECT COUNT(*) FROM orders WHERE orders.order_status = 'canceled')*100 / Count(order_id) AS 'Canceled %'
FROM orders

"""
cur.execute(query)
cur.fetchall()

pd.read_sql(query, conn)
# Out:
#    Total orders  Canceled Orders  Canceled %
# 0         99441              625           0

# %% [markdown]
# This query lists all the product IDs in that order (concatenated into a single string), and returns all orders, total price of orders and the payment type where total price is greater than 100. This may be used to know the total price of each order even it has more than 1 sold product in the invoice and how that orders are paid.

# %%
query = '''
SELECT
    COUNT(order_items.order_id) AS total_orders,
    GROUP_CONCAT(order_items.product_id) AS products,
    COUNT(order_items.product_id) AS total_products,
    SUM(order_items.price) AS total_price,
    order_payments.payment_type
FROM order_items
JOIN order_payments ON order_payments.order_id = order_items.order_id
GROUP BY order_items.order_id
HAVING total_price >= 100
'''
pd.read_sql(query,conn)
# Out:
#        total_orders                                           products  \
# 0                 1                   e5f2d52b802189ee658865ca93d83a8f
# 1                 1                   c777355d18b72b67abbeef9df44fd0fd
# 2                 1                   ac6c3623068f30de03045865e4e10089
# 3                 1                   557d850972a7d6f792fd18ae1400d9b6
# 4                 1                   310ae3c140ff94b03219ad0adc3c778f
# ...             ...                                                ...
# 41936             1                   bbe7651fef80287a816ead73f065fc4b
# 41937             4  43423cdffde7fda63d0414ed38c11a73,43423cdffde7f...
# 41938             1                   6f0169f259bb0ff432bfff7d829b9946
# 41939             1                   4aa6014eceb682077f9dc4bffebc05b0
# 41940             1                   32e07fd915822b0765e448c4dd74c828
#
#        total_products  total_price payment_type
# 0                   1       239.90  credit_card
# ...

# %% [markdown]
# We can use the following query to know about payment process of orders with specific order status.

# %%
query = '''
SELECT
    COUNT(order_items.order_id) AS total_orders,
    GROUP_CONCAT(order_items.product_id) AS products,
    COUNT(order_items.product_id) AS total_products,
    SUM(order_items.price) AS total_price,
    order_payments.payment_type,
    orders.order_status
FROM order_items
JOIN order_payments ON order_payments.order_id = order_items.order_id
JOIN orders ON order_items.order_id=orders.order_id
GROUP BY order_items.order_id
HAVING orders.order_status = 'invoiced'
'''
#HAVING orders.order_status = 'approved'
#HAVING orders.order_status = 'shipped'
#HAVING orders.order_status = 'delivered'
#HAVING orders.order_status = 'unavailable'
#HAVING orders.order_status = 'canceled'
#HAVING orders.order_status = 'processing'
#or order_status may be not specified
pd.read_sql(query,conn)
# Out:
#      total_orders                                           products  \
# 0               2  a0eccc912d428eaddf1ef4fe47593ece,a0eccc912d428...
# 1               1                   7535f3518e1009b17aa6e3fa553e82bc
# 2               1                   5f8c74f4a3d2b616857fcb7d4dd1f61a
# 3               1                   cf18e908cb8600dcd21a719db24c48d8
# 4               1                   f699b297070aa38aaf3de9639302506a
# ..            ...                                                ...
# 307             1                   d585c50d622ff40b4d69959caa42a5a3
# 308             2  663cce5b111af36144b6aad932e5a4ab,663cce5b111af...
# 309             1                   0c9439abe84dc40a64fc164365c4d064
# 310             1                   dc4c70ae91ccd3ee8e376c073b377f64
# 311             1                   18870238fd023ef96e834a59dbd4405f
#
#      total_products  total_price payment_type order_status
# 0                 2       286.00       boleto     invoiced
# ...

# %%
#Order's status and delivery time
query = '''
SELECT order_items.shipping_limit_date, COUNT(orders.order_id) AS total_orders, orders.order_status, orders.order_estimated_delivery_date
FROM order_items
JOIN orders ON order_items.order_id=orders.order_id
GROUP BY orders.order_status
'''
pd.read_sql(query, conn)
# Out:
#    shipping_limit_date  total_orders order_status  \
# 0  2017-05-08 20:32:41             3     approved
# 1  2018-08-17 15:04:25           542     canceled
# 2  2017-09-19 09:45:35        110197    delivered
# 3  2017-02-04 13:06:05           359     invoiced
# 4  2017-12-08 10:53:16           357   processing
# 5  2018-03-27 13:15:27          1185      shipped
# 6  2016-10-11 18:53:48             7  unavailable
#
#   order_estimated_delivery_date
# 0           2017-05-22 00:00:00
# 1           2018-08-29 00:00:00
# 2           2017-09-29 00:00:00
# 3           2017-03-09 00:00:00
# 4           2017-12-29 00:00:00
# 5           2018-04-16 00:00:00
# 6           2016-12-07 00:00:00

# %%
#price of delivered orders grouped by installments number
query = '''
SELECT order_items.price, orders.order_status, order_payments.payment_installments
FROM order_items
JOIN orders ON order_items.order_id=orders.order_id
JOIN order_payments ON orders.order_id=order_payments.order_id
WHERE orders.order_status = 'delivered'
GROUP BY order_payments.payment_installments
'''
pd.read_sql(query, conn)
# Out:
#       price order_status  payment_installments
# 0     45.90    delivered                     0
# 1     29.99    delivered                     1
# 2     47.90    delivered                     2
# 3    159.90    delivered                     3
# 4     27.99    delivered                     4
# 5     69.90    delivered                     5
# 6    147.90    delivered                     6
# 7    139.00    delivered                     7
# 8    178.99    delivered                     8
# 9     69.90    delivered                     9
# 10   132.40    delivered                    10
# 11    99.90    delivered                    11
# 12   109.99    delivered                    12
# 13   116.99    delivered                    13
# 14   229.90    delivered                    14
# 15  1437.00    delivered                    15
# 16   129.90    delivered                    16
# 17   129.90    delivered                    17
# 18  1200.00    delivered                    18
# ...

# %%
query = '''
SELECT COUNT(order_payments.order_id) AS unique_orders, COUNT(order_items.product_id) AS total_items, COUNT(order_payments.payment_sequential) AS total_payments
FROM order_payments
JOIN order_items ON order_payments.order_id=order_items.order_id
GROUP BY order_payments.order_id
HAVING total_payments > 5
'''
pd.read_sql(query, conn)
# Out:
#      unique_orders  total_items  total_payments
# 0                6            6               6
# 1                7            7               7
# 2                6            6               6
# 3                8            8               8
# 4                6            6               6
# ..             ...          ...             ...
# 435              6            6               6
# 436             12           12              12
# 437             38           38              38
# 438              6            6               6
# 439             12           12              12
#
# [440 rows x 3 columns]

# %%
query = """SELECT product_weight_g, product_length_cm, product_height_cm, product_width_cm, freight_value
FROM order_items
JOIN products ON order_items.product_id = products.product_id
WHERE freight_value IS NOT NULL

 ;"""
pd.read_sql(query, conn)
# Out:
#         product_weight_g  product_length_cm  product_height_cm  \
# 0                  650.0               28.0                9.0
# 1                30000.0               50.0               30.0
# 2                 3050.0               33.0               13.0
# 3                  200.0               16.0               10.0
# 4                 3750.0               35.0               40.0
# ...                  ...                ...                ...
# 112645           10150.0               89.0               15.0
# 112646            8950.0               45.0               26.0
# 112647             967.0               21.0               24.0
# 112648             100.0               20.0               20.0
# 112649             600.0               30.0                3.0
#
#         product_width_cm  freight_value
# 0                   14.0          13.29
# 1                   40.0          19.93
# 2                   33.0          17.87
# 3                   15.0          12.79
# ...

# %%
import seaborn as sns
data = pd.read_sql_query(query, conn)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='product_weight_g', y='freight_value', data=data)

plt.title('Product Weight vs. Freight Value', fontsize=16)
plt.xlabel('Product Weight (g)', fontsize=14)
plt.ylabel('Freight Value', fontsize=14)
plt.tight_layout()
plt.show()

# %%
bins = [0, 1000, 5000, 10000, 50000]
labels = ['Small', 'Medium', 'Large', 'Very Large']
data['weight_category'] = pd.cut(data['product_weight_g'], bins=bins, labels=labels)

plt.figure(figsize=(10, 6))
sns.boxplot(x='weight_category', y='freight_value', data=data, palette='coolwarm')

plt.title('Freight Value Distribution by Product Weight Category (Box Plot)', fontsize=16)
plt.xlabel('Weight Category', fontsize=14)
plt.ylabel('Freight Value', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-53-44856ae607dc>:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
#Analyzing the relationship between product price and freight value can reveal patterns in shipping costs relative to product price.

order_items_df = pd.read_sql_query("SELECT price, freight_value FROM order_items", conn)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='freight_value', data=order_items_df)
plt.title('Freight Value vs. Price')
plt.xlabel('Price')
plt.ylabel('Freight Value')
plt.show()

# %% [markdown]
# # Reviews

# %%
query = """SELECT review_score, COUNT(*) AS count
FROM order_reviews
GROUP BY review_score
ORDER BY review_score
 ;"""
pd.read_sql(query, conn)
# Out:
#    review_score  count
# 0             1  11424
# 1             2   3151
# 2             3   8179
# 3             4  19142
# 4             5  57328

# %%
import plotly.express as px
data = pd.read_sql_query(query, conn)
data = data.sort_values(by='count', ascending=False)
fig = px.bar(data, x='review_score', y='count',
             title='Review Score Distribution',
             labels={'review_score': 'Review Score', 'count': 'Number of Reviews'},
             color='review_score', color_continuous_scale='Viridis')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Bar(x=data['review_score'], y=data['count'], name='Reviews',
                     marker=dict(color='blue')))

fig.update_layout(
    barmode='stack',
    title="Stacked Bar Chart Example",
    xaxis_title="Review Score",
    yaxis_title="Count of Reviews"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Rating for the product category and total sold items
query = '''
SELECT
order_reviews.review_score, products.product_category_name, COUNT(order_items.product_id) AS total_sold
FROM order_items
JOIN order_reviews ON order_items.order_id=order_reviews.order_id
JOIN products ON order_items.product_id=products.product_id
GROUP BY order_reviews.review_score
'''
pd.read_sql(query, conn)
# Out:
#    review_score product_category_name  total_sold
# 0             1          beleza_saude       14235
# 1             2      moveis_decoracao        3874
# 2             3            cool_stuff        9423
# 3             4              pet_shop       21315
# 4             5            cool_stuff       63525

# %% [markdown]
# # Delivery Analysis

# %%
query = """SELECT order_id, order_purchase_timestamp,
       order_delivered_customer_date, order_estimated_delivery_date
FROM orders
WHERE order_status = 'delivered';

"""
df = pd.read_sql(query, conn)
df["order_purchase_timestamp"] = pd.to_datetime(df["order_purchase_timestamp"])
df["order_delivered_customer_date"] = pd.to_datetime(df["order_delivered_customer_date"])
df["order_estimated_delivery_date"] = pd.to_datetime(df["order_estimated_delivery_date"])
df["actual_delivery_days"] = (df["order_delivered_customer_date"] - df["order_purchase_timestamp"]).dt.days
df["estimated_delivery_days"] = (df["order_estimated_delivery_date"] - df["order_purchase_timestamp"]).dt.days

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["order_purchase_timestamp"], df["actual_delivery_days"], label="Actual Delivery Days", marker='o')
plt.plot(df["order_purchase_timestamp"], df["estimated_delivery_days"], label="Estimated Delivery Days", marker='o', linestyle='--')

plt.xlabel("Order Purchase Timestamp")
plt.ylabel("Delivery Days")
plt.title("Comparison of Actual vs. Estimated Delivery")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Aggregate by Month for Better Visualization

# %%
df["purchase_month"] = df["order_purchase_timestamp"].dt.to_period("M")
monthly_summary = df.groupby("purchase_month")[["actual_delivery_days", "estimated_delivery_days"]].mean()

plt.figure(figsize=(12, 6))
plt.plot(monthly_summary.index.astype(str), monthly_summary["actual_delivery_days"], label="Actual Delivery Days", marker='o')
plt.plot(monthly_summary.index.astype(str), monthly_summary["estimated_delivery_days"], label="Estimated Delivery Days", marker='o', linestyle='--')

plt.xlabel("Month")
plt.ylabel("Average Delivery Days")
plt.title("Monthly Comparison of Actual vs. Estimated Delivery")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
query = """
SELECT order_id, order_purchase_timestamp, order_approved_at,
       order_delivered_carrier_date, order_delivered_customer_date
FROM orders
WHERE order_status = 'delivered';
"""
df = pd.read_sql(query, conn)

# %%
df["order_purchase_timestamp"] = pd.to_datetime(df["order_purchase_timestamp"])
df["order_approved_at"] = pd.to_datetime(df["order_approved_at"])
df["order_delivered_carrier_date"] = pd.to_datetime(df["order_delivered_carrier_date"])
df["order_delivered_customer_date"] = pd.to_datetime(df["order_delivered_customer_date"])

# %%
df["purchase_to_approval"] = (df["order_approved_at"] - df["order_purchase_timestamp"]).dt.total_seconds() / 3600
df["approval_to_carrier"] = (df["order_delivered_carrier_date"] - df["order_approved_at"]).dt.total_seconds() / 3600
df["carrier_to_customer"] = (df["order_delivered_customer_date"] - df["order_delivered_carrier_date"]).dt.total_seconds() / 3600

print(df[["purchase_to_approval", "approval_to_carrier", "carrier_to_customer"]].head())
# Out:
#    purchase_to_approval  approval_to_carrier  carrier_to_customer
# 0              0.178333            56.795833           145.503611
# 1             30.713889            11.109167           288.945833
# 2              0.276111             4.910278           220.274722
# 3              0.298056            89.900000           226.811944
# 4              1.030556            21.434722            46.507778

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["order_purchase_timestamp"], df["purchase_to_approval"], label="Purchase to Approval", marker='o')
plt.plot(df["order_purchase_timestamp"], df["approval_to_carrier"], label="Approval to Carrier Delivery", marker='o')
plt.plot(df["order_purchase_timestamp"], df["carrier_to_customer"], label="Carrier Delivery to Customer", marker='o')

plt.xlabel("Order Purchase Timestamp")
plt.ylabel("Duration (Hours)")
plt.title("Delivery Timeline Trends")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Aggregate by Month for Better Visualization

# %%
df["purchase_month"] = df["order_purchase_timestamp"].dt.to_period("M")

monthly_summary = df.groupby("purchase_month")[["purchase_to_approval", "approval_to_carrier", "carrier_to_customer"]].mean()

plt.figure(figsize=(12, 6))
plt.plot(monthly_summary.index.astype(str), monthly_summary["purchase_to_approval"], label="Purchase to Approval", marker='o')
plt.plot(monthly_summary.index.astype(str), monthly_summary["approval_to_carrier"], label="Approval to Carrier Delivery", marker='o')
plt.plot(monthly_summary.index.astype(str), monthly_summary["carrier_to_customer"], label="Carrier Delivery to Customer", marker='o')

plt.xlabel("Month")
plt.ylabel("Average Duration (Hours)")
plt.title("Monthly Delivery Timeline Trends")
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
query = """
SELECT customer_id, customer_unique_id, customer_zip_code_prefix,
       customer_city, customer_state
FROM customers;
"""
customers_df = pd.read_sql(query, conn)

# %%
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
query = """
SELECT customer_id, COUNT(order_id) AS order_count
FROM orders
GROUP BY customer_id
ORDER BY order_count DESC
LIMIT 1000;
"""
top1000_df = pd.read_sql(query, conn)
top1000_df
# Out:
#                           customer_id  order_count
# 0    ffffe8b65bbe3087b653a978c870db99            1
# 1    ffffa3172527f765de70084a7e53aae8            1
# 2    ffff42319e9b2d713724ae527742af25            1
# 3    fffeda5b6d849fbd39689bb92087f431            1
# 4    fffecc9f79fd8c764f843e9951b11341            1
# ..                                ...          ...
# 995  fd8622c9fc0a00dc505ba474a4fe36cd            1
# 996  fd845a6b26fb28a1ed6c59f9a58d0cc6            1
# 997  fd82f1f6243134cada673eb5c862ee33            1
# 998  fd826e7cf63160e536e0908c76c3f441            1
# 999  fd80fe1d9709f6dd159fc642a4f45bb9            1
#
# [1000 rows x 2 columns]

# %%
city_counts = customers_df["customer_city"].value_counts()
top_cities = city_counts[city_counts > 500].index
filtered_df = customers_df[customers_df["customer_city"].isin(top_cities)]

# %%
filtered_df
# Out:
#                             customer_id                customer_unique_id  \
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 6      fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 8      5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# ...                                 ...                               ...
# 99423  c6ece8a5137f3c9c3a3a12302a19a2ac  aaf22868003377e859049dcf5f0b3fdf
# 99425  0a7db3996b88954c7aa763b5dd621d5b  15637b62dfa4c5a9df846b22beef0994
# 99426  935993f47af1ed7d0715c26b686341c5  4452b8ef472646c4cc042cb31a291f3b
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
query = """
SELECT
    customer_city,
    COUNT(customer_id) AS customer_count
FROM customers
GROUP BY customer_city
HAVING COUNT(customer_id) > 500
ORDER BY customer_count DESC;
"""

city_customer_counts_df = pd.read_sql(query, conn)

print(city_customer_counts_df)
# Out:
#             customer_city  customer_count
# 0               sao paulo           15540
# 1          rio de janeiro            6882
# 2          belo horizonte            2773
# 3                brasilia            2131
# 4                curitiba            1521
# 5                campinas            1444
# 6            porto alegre            1379
# 7                salvador            1245
# 8               guarulhos            1189
# 9   sao bernardo do campo             938
# 10                niteroi             849
# 11            santo andre             797
# 12                 osasco             746
# 13                 santos             713
# 14                goiania             692
# 15    sao jose dos campos             691
# 16              fortaleza             654
# 17               sorocaba             633
# 18                 recife             613
# 19          florianopolis             570
# 20                jundiai             565
# ...

# %%
pip install geopy

# %%
pip install folium

# %%
from geopy.geocoders import Nominatim
import pandas as pd

# Initialize geolocator
geolocator = Nominatim(user_agent="customer_geolocator")

# Function to get latitude and longitude of a city
def geocode_city(city, state):
    try:
        location = geolocator.geocode(f"{city}, {state}, Brazil", timeout=10)  # Increased timeout
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except Exception as e:
        print(f"Error geocoding {city}: {e}")
        return None, None

# Apply the function to dataframe
city_customer_counts_df[['latitude', 'longitude']] = city_customer_counts_df.apply(
    lambda row: pd.Series(geocode_city(row['customer_city'], 'SP')), axis=1
)

print(city_customer_counts_df[['customer_city', 'latitude', 'longitude']].head())
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=10)")': /search?q=santo+andre%2C+SP%2C+Brazil&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=10)")': /search?q=jundiai%2C+SP%2C+Brazil&format=json&limit=1
#     customer_city   latitude  longitude
# 0       sao paulo -23.550651 -46.633382
# 1  rio de janeiro -23.446120 -46.536005
# 2  belo horizonte -22.579301 -46.693963
# 3        brasilia -22.454353 -49.231383
# 4        curitiba -20.434232 -51.351734

# %%
import plotly.express as px

fig = px.scatter_geo(
    city_customer_counts_df,
    lat="latitude",
    lon="longitude",
    hover_name="customer_city",
    size="customer_count",
    scope="south america",
    title="Customer Distribution in Brazil"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import folium

brazil_map = folium.Map(location=[-14.2350, -51.9253], zoom_start=4)

# Add customer cities as markers on the map
for _, row in city_customer_counts_df.iterrows():
    if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=8,  # Adjust size
            color="blue",
            fill=True,
            fill_color="blue",
            fill_opacity=0.6,
            popup=f"{row['customer_city']}: {row['customer_count']} customers"
        ).add_to(brazil_map)

brazil_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Fetch data from SQL (adjust query as needed)
query = "SELECT * FROM leads_closed LIMIT 100;"
df = pd.read_sql(query, conn)


# Remove rows with NaN values in the important columns
df_clean = df.dropna(subset=['declared_monthly_revenue', 'declared_product_catalog_size', 'average_stock'])
fig = px.sunburst(
    df_clean,
    path=['business_segment', 'lead_type'],  # Hierarchical path
    values='declared_monthly_revenue',  # Size of sectors based on revenue
    title='Revenue by Business Segment and Lead Type'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Analysis of Qualified Leads

# %%
#Analysis of Closed Leads by Origin
query = """

SELECT origin,
COUNT(*),
ROUND(CAST(COUNT(*)*100.0/ (SELECT COUNT(*) FROM leads_qualified) AS FLOAT),3) AS Percentage
FROM leads_qualified

GROUP BY origin

ORDER BY COUNT(*) DESC

"""
cur.execute(query)
cur.fetchall()

pd.read_sql(query, conn)
# Out:
#                origin  COUNT(*)  Percentage
# 0      organic_search      2296      28.700
# 1         paid_search      1586      19.825
# 2              social      1350      16.875
# 3             unknown      1099      13.738
# 4      direct_traffic       499       6.238
# 5               email       493       6.163
# 6            referral       284       3.550
# 7               other       150       1.875
# 8             display       118       1.475
# 9   other_publicities        65       0.813
# 10               None        60       0.750

# %%
#Analysis of Closed Leads by Business Segment
query = """

SELECT COUNT(*) as lead_count, business_segment,
ROUND(COUNT(*) *100.0 / (SELECT COUNT(*) FROM leads_closed),2)  AS 'Percentage'
FROM leads_closed
GROUP BY business_segment
ORDER BY  COUNT(*) DESC

LIMIT 10

"""
cur.execute(query)
cur.fetchall()

segment_data = pd.read_sql(query, conn)
segment_data
# Out:
#    lead_count                 business_segment  Percentage
# 0         105                       home_decor       12.47
# 1          93                    health_beauty       11.05
# 2          77                  car_accessories        9.14
# 3          71              household_utilities        8.43
# 4          69  construction_tools_house_garden        8.19
# 5          64          audio_video_electronics        7.60
# 6          34                        computers        4.04
# 7          30                              pet        3.56
# 8          28                  food_supplement        3.33
# 9          26                       food_drink        3.09

# %%
plt.figure(figsize=(10, 6))
plt.barh(segment_data['business_segment'], segment_data['lead_count'], color='teal')
plt.xlabel('Number of Closed Leads', fontsize=12)
plt.ylabel('Business Segment', fontsize=12)
plt.title('Closed Leads by Business Segment', fontsize=16)
plt.gca().invert_yaxis()  # Invert y-axis for better readability
plt.tight_layout()
plt.show()

# %%
fig = px.pie(segment_data, values='Percentage', names='business_segment',
             title='Closed Leads Percentage by Business Segment')

# Add a hole to create a donut chart
fig.update_traces(textinfo='percent+label', hole=0.4)

# Update layout
fig.update_layout(title_font_size=20)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
